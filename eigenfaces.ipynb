# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from PIL import Image

image_pil = Image.open('./Caltech_WebFaces/pic00010.jpg')
image_pil = image_pil.convert('L')
image = np.array(image_pil)
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image_pil
# Out:
# <PIL.Image.Image image mode=L size=217x250>

# %%
image.shape
# Out:
# (250, 217)

# %%
image.size
# Out:
# 54250

# %%
image
# Out:
# array([[ 45,  43,  41, ...,  54,  50,  43],
#        [ 41,  39,  38, ...,  50,  45,  44],
#        [ 40,  38,  36, ...,  48,  44,  43],
#        ...,
#        [175, 164, 147, ..., 161, 203, 230],
#        [177, 172, 161, ..., 192, 205, 227],
#        [176, 169, 155, ..., 205, 218, 227]], dtype=uint8)

# %%
image.T
# Out:
# array([[ 45,  41,  40, ..., 175, 177, 176],
#        [ 43,  39,  38, ..., 164, 172, 169],
#        [ 41,  38,  36, ..., 147, 161, 155],
#        ...,
#        [ 54,  50,  48, ..., 161, 192, 205],
#        [ 50,  45,  44, ..., 203, 205, 218],
#        [ 43,  44,  43, ..., 230, 227, 227]], dtype=uint8)

# %%
image = np.array([image.T.ravel()]).T

# %%
image
# Out:
# array([[ 45],
#        [ 41],
#        [ 40],
#        ...,
#        [230],
#        [227],
#        [227]], dtype=uint8)

# %%
image.shape
# Out:
# (54250, 1)

# %%
image.size
# Out:
# 54250
